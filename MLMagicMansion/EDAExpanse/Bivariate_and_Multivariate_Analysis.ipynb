# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
titanic = pd.read_csv('train.csv')

# %%
flights = sns.load_dataset('flights')

# %%
iris = sns.load_dataset('iris')

# %% [markdown]
# # Numerical and Numerical -- ScatterPLot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x = 'total_bill' , y = 'tip' ,hue = 'sex' ,style = 'smoker' ,  data = tips , size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# LinePLot
#
# - time based
#
#
# > there is some issue will update as sson as possible

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights['year'] = pd.to_numeric(flights['year'], errors='coerce').astype('Int64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 11
#       8 flights['year'] = pd.to_numeric(flights['year'], errors='coerce').astype('Int64')
#      10 # Group by 'year' and sum the values
# ---> 11 yearly_flights = flights.groupby('year').sum().reset_index()
#      13 # Create a line plot using Seaborn
#      14 plt.figure(figsize=(10, 6))
#
# File D:\Users\srish\PycharmProjects\Environments\DataCrafters\Lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# ...

# %%
yearly_flights = flights.groupby('year').sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 yearly_flights = flights.groupby('year').sum().reset_index()
#
# File D:\Users\srish\PycharmProjects\Environments\DataCrafters\Lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
#    3150             npfunc=np.sum,
#    3151         )
# ...

# %% [markdown]
# # Numerical and Categorical -- BarPlot , BoxPlot , DistPlot

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(x = "Pclass" , y = "Age" , data=titanic , hue = 'Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x = 'Sex' , y = 'Age' , data = titanic , hue = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'])
sns.distplot(titanic[titanic['Survived']==1]['Age'])
# Out:
# C:\Users\srish\AppData\Local\Temp\ipykernel_34288\3942892072.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'])
# C:\Users\srish\AppData\Local\Temp\ipykernel_34288\3942892072.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# Using sns.distplot in Seaborn allows you to visualize the distribution of data. However, note that sns.distplot has been deprecated and replaced by sns.histplot and sns.kdeplot in newer versions of Seaborn. For distribution plots without histograms, sns.kdeplot is recommended.

# %%
sns.histplot(titanic[titanic['Survived'] == 0]['Age'], kde=True, color='red', label='Did Not Survive', bins=30)

sns.histplot(titanic[titanic['Survived'] == 1]['Age'], kde=True, color='blue', label='Survived', bins=30)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(data=titanic[titanic['Survived'] == 0]['Age'], label='Did Not Survive', shade=True)

sns.kdeplot(data=titanic[titanic['Survived'] == 1]['Age'], label='Survived', shade=True)
# Out:
# C:\Users\srish\AppData\Local\Temp\ipykernel_34288\3979383069.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=titanic[titanic['Survived'] == 0]['Age'], label='Did Not Survive', shade=True)
# C:\Users\srish\AppData\Local\Temp\ipykernel_34288\3979383069.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=titanic[titanic['Survived'] == 1]['Age'], label='Survived', shade=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # Categorical and Categorical --- HeatMap , Clustermap , PairPlot

# %%
pd.crosstab(titanic['Pclass'] , titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'] , titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
(titanic.groupby('Pclass')['Survived'].mean()*100).plot(kind = "bar" )
# Out:
# <Axes: xlabel='Pclass'>

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.14.0

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'] , titanic['Survived']))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 sns.clustermap(pd.crosstab(titanic['SibSp'] , titanic['Survived']) , cmap = 'viridis')
#
# File D:\Users\srish\PycharmProjects\Environments\DataCrafters\Lib\site-packages\seaborn\matrix.py:1250, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1157 """
#    1158 Plot a matrix dataset as a hierarchically-clustered heatmap.
#    1159
#    (...)
#    1247
#    1248 """
#    1249 if _no_scipy:
# -> 1250     raise RuntimeError("clustermap requires scipy to be available")
#    1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
# ...

# %%
pd.crosstab(titanic['SibSp'] , titanic['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %% [markdown]
# PairPlot

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris , hue = 'species')
